# %%
d={"key":"val1","key1":"val2"}

# %%
d['key1']
# Out:
# 'val2'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
pip install python-box
# Out:
# Requirement already satisfied: python-box in e:\new folder\envs\kidney\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox
d=ConfigBox({"key":"val1","key1":"val2"})
d.key
# Out:
# 'val1'

# %%
#ensure annotations
def get_prodict(x: int,y: int)-> int:
    return x+y
get_prodict(2,3)
# Out:
# 5

# %%
get_prodict(x='2',y="3")
# Out:
# '23'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x + y

# %%
get_prodict(2,3)
# Out:
# 5

# %%
get_prodict(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_prodict(x=2,y="3")
#
# Cell In[12], line 3, in get_prodict(x, y)
#       2 def get_prodict(x: int,y: int)-> int:
# ----> 3     return x+y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
## download data from google drive
import gdown
url='https://drive.google.com/file/d/1FSQuxlLu2nGuBAPkeEmGUqhTbwlNs-v9/view?usp=drive_link'
file_id=url.split('/')[-2]
file_id
prefix='https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id,"kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1FSQuxlLu2nGuBAPkeEmGUqhTbwlNs-v9
# From (redirected): https://drive.google.com/uc?export=download&id=1FSQuxlLu2nGuBAPkeEmGUqhTbwlNs-v9&confirm=t&uuid=f2c75379-23f4-428a-bd06-7091ad02e1cb
# To: e:\Kidney project\Kidney-disease-classification-with-mlflow-dvc\research\kidney-CT-Scan-data.zip
# 100%|██████████| 940M/940M [01:22<00:00, 11.4MB/s]
# 'kidney-CT-Scan-data.zip'

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '1YCMM5JZOHwbRCaSNN1N9k_EZlI6bM69N'

# %%
prefix='https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id,"kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1YCMM5JZOHwbRCaSNN1N9k_EZlI6bM69N
# From (redirected): https://drive.google.com/uc?export=download&id=1YCMM5JZOHwbRCaSNN1N9k_EZlI6bM69N&confirm=t&uuid=20bc4961-0cc2-4d08-a4a3-f5197de50eb1
# To: e:\Kidney project\Kidney-disease-classification-with-mlflow-dvc\research\kidney-CT-Scan-data.zip
# 100%|██████████| 925M/925M [02:24<00:00, 6.39MB/s]
# 'kidney-CT-Scan-data.zip'

# %%
pip install python-box
# Out:
# Requirement already satisfied: python-box in e:\new folder\envs\kidney\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-box
# Out:
# Requirement already satisfied: python-box in e:\new folder\envs\kidney\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox
# Out:
#   Cell In[1], line 2
#     pip show python-box
#         ^
# SyntaxError: invalid syntax
